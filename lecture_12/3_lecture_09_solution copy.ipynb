# %% [markdown]
# # <span style="color:red; font-size:30px"> Lecture 09 Solution</span>

# %% [markdown]
# <font size = "4">
#
# The notebooks in the lecture_12 folder are intended to fill in some gaps of the content that we haven't reached yet, in order to help with Assignment #4 and preparation for Quiz #2

# %% [markdown]
# <font size = "5">
#
# **From the end of Lecture 09**:
#
# <font size = "4">
#
# Try it yourself!
#
# - Repeat the above simulation with a few changes
# - Write code that puts all the figures in the same row
# - Use a Chi-square distribution with (df = 1) instead of a normal

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
num_simulations = 2000
sample_size_list = [1,10,50,100,150,200]
fig_row = [0, 0, 0, 1, 1, 1]
fig_col = [0, 1, 2, 0, 1, 2]


fig, subfig_array = plt.subplots(2, 3, figsize = (9,6))

xmin = 0
xmax = 2
ymax = 1600

for sample_sz, row, col in zip(sample_size_list, fig_row, fig_col):

    vec_xbar = np.zeros(num_simulations)
    for iteration in range(num_simulations):
        vec_unif  = np.random.chisquare(df = 1, size = sample_sz)
        vec_xbar[iteration] = vec_unif.mean()

    subfig_array[row,col].hist(vec_xbar)
    subfig_array[row,col].set_title("Sample Mean of $\chi^2$-distribution:\n sample size " + str(sample_sz))
    subfig_array[row,col].set_ylabel("Frequency")
    subfig_array[row,col].set_xlabel("Values of Xbar") 
    subfig_array[row,col].set_xlim(xmin,xmax) 
    subfig_array[row,col].set_ylim(top=ymax)  

plt.tight_layout()

# %%
num_simulations = 2000
sample_size_list = [1,10,50,100,150,200]
fig_row = [0, 0, 0, 1, 1, 1]
fig_col = [0, 1, 2, 0, 1, 2]


fig, subfig_array = plt.subplots(2, 3, figsize = (9,6))

xmin = -2
xmax = 2
ymax = 600

for sample_sz, row, col in zip(sample_size_list, fig_row, fig_col):

    vec_xbar = np.zeros(num_simulations) #will have array with 0s length 2000. store all teh sample means.
    for iteration in range(num_simulations):#loop runs 2000 times and each time is 1 simulated experiment
        vec_unif  = np.random.uniform(low = -2, high=2, size = sample_sz)#random numbers from uniform -2, 2. this is one random sample.
        vec_xbar[iteration] = vec_unif.mean()#mean of sample. store in position of iteration of vec_ebar.

    subfig_array[row,col].hist(vec_xbar)
    subfig_array[row,col].set_title("Distribution of Xbar with\n sample size " + str(sample_sz))
    subfig_array[row,col].set_ylabel("Frequency")
    subfig_array[row,col].set_xlabel("Values of Xbar") 
    subfig_array[row,col].set_xlim(xmin,xmax) 
    subfig_array[row,col].set_ylim(top=ymax)  

plt.tight_layout()
